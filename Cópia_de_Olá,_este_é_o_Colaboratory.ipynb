# %% [markdown]
# <a href="https://colab.research.google.com/github/ledaSantos/-Aventura-Javascript/blob/main/C%C3%B3pia_de_Ol%C3%A1%2C_este_%C3%A9_o_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2024.9.4-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.1.0)
# Downloading rdkit-2024.9.4-cp311-cp311-manylinux_2_28_x86_64.whl (34.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.2/34.2 MB 11.6 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2024.9.4

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'C'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'CC'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'CCO'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'CC(=O)O'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'CC(=O)C'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'c1ccccc1O'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'c1ccccc1'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'C6H5CH3'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'C1CCCCC1'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'CCCC'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'CC(=O)OCC'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'c1ccccc1N'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'c1ccc(cc1O)O'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'C=CC'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors, Crippen, Lipinski

#Definir nosso smiles

smiles = 'C(Cl)ClCl'

#import da biblioteca

mol =Chem.MolFromSmiles(smiles)

#pedir o desenho
img = Draw.MolToImage(mol)

display(img)
# Out:
# [00:38:44] Explicit valence for atom # 2 Cl, 2, is greater than permitted
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-3b90b1c7dffe> in <cell line: 0>()
#      12
#      13 #pedir o desenho
# ---> 14 img = Draw.MolToImage(mol)
#      15
#      16 display(img)
#
# /usr/local/lib/python3.11/dist-packages/rdkit/Chem/Draw/__init__.py in MolToImage(mol, size, kekulize, wedgeBonds, fitImage, options, **kwargs)
#      99   """
#     100   if not mol:
# --> 101     raise ValueError('Null molecule provided')
#     102   if not hasattr(rdMolDraw2D, 'MolDraw2DCairo'):
#     103     raise RuntimeError("MolToImage requires that the RDKit be built with Cairo support")
#
# ValueError: Null molecule provided
